# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline  
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("D:\DATA SCIENCE\FSDS - May 22\EDA\Algerian_forest_fires_dataset_UPDATE.csv",header = 1)

# %%
df
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI   BUI  \
# 0    01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3   3.4
# 1    02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1   3.9
# 2    03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3   2.7
# 3    04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0   1.7
# 4    05    06  2012          27  77  16     0  64.8    3  14.2  1.2   3.9
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...   ...
# 241  26    09  2012          30  65  14     0  85.4   16  44.5  4.5  16.9
# 242  27    09  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 243  28    09  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 244  29    09  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 245  30    09  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#      FWI     Classes
# 0    0.5   not fire
# 1    0.4   not fire
# ...

# %%
df[0:125]
# Out:
#                                day  month  year  Temperature   RH   Ws  Rain   \
# 0                               01     06  2012           29   57   18      0
# 1                               02     06  2012           29   61   13    1.3
# 2                               03     06  2012           26   82   22   13.1
# 3                               04     06  2012           25   89   13    2.5
# 4                               05     06  2012           27   77   16      0
# ..                             ...    ...   ...          ...  ...  ...    ...
# 120                             29     09  2012           26   80   16    1.8
# 121                             30     09  2012           25   78   14    1.4
# 122  Sidi-Bel Abbes Region Dataset    NaN   NaN          NaN  NaN  NaN    NaN
# 123                            day  month  year  Temperature   RH   Ws  Rain
# 124                             01     06  2012           32   71   12    0.7
#
# ...

# %%
df.drop([122,123],inplace = True,axis=0)

# %%
df[0:126]
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0    01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1    02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2    03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3    04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4    05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...  ...  ...
# 121  30    09  2012          25  78  14   1.4    45  1.9   7.5  0.2  2.4  0.1
# 124  01    06  2012          32  71  12   0.7  57.1  2.5   8.2  0.6  2.8  0.2
# 125  02    06  2012          30  73  13     4  55.7  2.7   7.8  0.6  2.9  0.2
# 126  03    06  2012          29  80  14     2  48.7  2.2   7.6  0.3  2.6  0.1
# 127  04    06  2012          30  64  14     0  79.4  5.2  15.4  2.2  5.6    1
#
#        Classes
# 0    not fire
# ...

# %%
df=df.reset_index(drop=True)

# %%
df[0:126]
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0    01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1    02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2    03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3    04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4    05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...  ...  ...
# 121  30    09  2012          25  78  14   1.4    45  1.9   7.5  0.2  2.4  0.1
# 122  01    06  2012          32  71  12   0.7  57.1  2.5   8.2  0.6  2.8  0.2
# 123  02    06  2012          30  73  13     4  55.7  2.7   7.8  0.6  2.9  0.2
# 124  03    06  2012          29  80  14     2  48.7  2.2   7.6  0.3  2.6  0.1
# 125  04    06  2012          30  64  14     0  79.4  5.2  15.4  2.2  5.6    1
#
#        Classes
# 0    not fire
# ...

# %%
df.loc[:122,'region']='Bejaia'
df.loc[122:,'region']='Sidi-Bel Abbes'

# %%
df[:122]
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI  BUI  FWI  \
# 0    01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3  3.4  0.5
# 1    02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1  3.9  0.4
# 2    03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3    04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0  1.7    0
# 4    05    06  2012          27  77  16     0  64.8    3  14.2  1.2  3.9  0.5
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...  ...  ...
# 117  26    09  2012          31  54  11     0    82    6  16.3  2.5  6.2  1.7
# 118  27    09  2012          31  66  11     0  85.7  8.3  24.9    4    9  4.1
# 119  28    09  2012          32  47  14   0.7  77.5  7.1   8.8  1.8  6.8  0.9
# 120  29    09  2012          26  80  16   1.8  47.4  2.9   7.7  0.3    3  0.1
# 121  30    09  2012          25  78  14   1.4    45  1.9   7.5  0.2  2.4  0.1
#
#        Classes    region
# ...

# %%
df[122:]
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI   BUI  \
# 122  01    06  2012          32  71  12   0.7  57.1  2.5   8.2  0.6   2.8
# 123  02    06  2012          30  73  13     4  55.7  2.7   7.8  0.6   2.9
# 124  03    06  2012          29  80  14     2  48.7  2.2   7.6  0.3   2.6
# 125  04    06  2012          30  64  14     0  79.4  5.2  15.4  2.2   5.6
# 126  05    06  2012          32  60  14   0.2  77.1    6  17.6  1.8   6.5
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...   ...
# 239  26    09  2012          30  65  14     0  85.4   16  44.5  4.5  16.9
# 240  27    09  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 241  28    09  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 242  29    09  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 243  30    09  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#      FWI     Classes            region
# 122  0.2   not fire     Sidi-Bel Abbes
# ...

# %%
df.shape
# Out:
# (244, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          244 non-null    object
#  1   month        244 non-null    object
#  2   year         244 non-null    object
#  3   Temperature  244 non-null    object
#  4    RH          244 non-null    object
#  5    Ws          244 non-null    object
#  6   Rain         244 non-null    object
#  7   FFMC         244 non-null    object
#  8   DMC          244 non-null    object
#  9   DC           244 non-null    object
#  10  ISI          244 non-null    object
#  11  BUI          244 non-null    object
#  12  FWI          244 non-null    object
#  13  Classes      243 non-null    object
#  14  region       244 non-null    object
# dtypes: object(15)
# memory usage: 28.7+ KB

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', ' RH', ' Ws', 'Rain ', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes  ', 'region'],
#       dtype='object')

# %%
df.rename(columns={' RH':'RH',' Ws':'Ws','Rain ':'Rain','Classes  ':'Classes'},inplace=True)

# %%
df.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'region'],
#       dtype='object')

# %%
df['day'] = df['day'].astype('int64')
df['month'] = df['month'].astype('int64')
df['year'] = df['year'].astype('int64')
df['Temperature'] = df['Temperature'].astype('int64')
df['RH'] = df['RH'].astype('int64')
df['Ws'] = df['Ws'].astype('int64')
df['Rain'] = df['Rain'].astype('float64')
df['FFMC'] = df['FFMC'].astype('float64')
df['DMC'] = df['DMC'].astype('float64')
df['ISI'] = df['ISI'].astype('float64')
df['BUI'] = df['BUI'].astype('float64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          244 non-null    int64
#  1   month        244 non-null    int64
#  2   year         244 non-null    int64
#  3   Temperature  244 non-null    int64
#  4   RH           244 non-null    int64
#  5   Ws           244 non-null    int64
#  6   Rain         244 non-null    float64
#  7   FFMC         244 non-null    float64
#  8   DMC          244 non-null    float64
#  9   DC           244 non-null    object
#  10  ISI          244 non-null    float64
#  11  BUI          244 non-null    float64
#  12  FWI          244 non-null    object
#  13  Classes      243 non-null    object
#  14  region       244 non-null    object
# dtypes: float64(5), int64(6), object(4)
# memory usage: 28.7+ KB

# %%
df.index[df['DC']=='14.6 9']
# Out:
# Int64Index([165], dtype='int64')

# %%
df[165:]
# Out:
#      day  month  year  Temperature  RH  Ws  Rain  FFMC   DMC      DC   ISI  \
# 165   14      7  2012           37  37  18   0.2  88.9  12.9  14.6 9  12.5
# 166   15      7  2012           34  45  17   0.0  90.5  18.0    24.1  10.9
# 167   16      7  2012           31  83  17   0.0  84.5  19.4    33.1   4.7
# 168   17      7  2012           32  81  17   0.0  84.6  21.1    42.3   4.7
# 169   18      7  2012           33  68  15   0.0  86.1  23.9    51.6   5.2
# ..   ...    ...   ...          ...  ..  ..   ...   ...   ...     ...   ...
# 239   26      9  2012           30  65  14   0.0  85.4  16.0    44.5   4.5
# 240   27      9  2012           28  87  15   4.4  41.1   6.5       8   0.1
# 241   28      9  2012           27  87  29   0.5  45.9   3.5     7.9   0.4
# 242   29      9  2012           24  54  18   0.1  79.7   4.3    15.2   1.7
# 243   30      9  2012           24  64  15   0.2  67.3   3.8    16.5   1.2
#
#       BUI      FWI       Classes          region
# ...

# %%
df.loc[165,'DC']=14.6

# %%
df.loc[165,'FWI']=df['FWI'].mode()[0]

# %%
df['FWI'].value_counts()
# Out:
# 0.4    13
# 0.8    10
# 0.5     9
# 0.1     9
# 0       9
#        ..
# 7.5     1
# 8.3     1
# 9.7     1
# 8.4     1
# 6.5     1
# Name: FWI, Length: 126, dtype: int64

# %%
df[165:]
# Out:
#      day  month  year  Temperature  RH  Ws  Rain  FFMC   DMC    DC   ISI  \
# 165   14      7  2012           37  37  18   0.2  88.9  12.9  14.6  12.5
# 166   15      7  2012           34  45  17   0.0  90.5  18.0  24.1  10.9
# 167   16      7  2012           31  83  17   0.0  84.5  19.4  33.1   4.7
# 168   17      7  2012           32  81  17   0.0  84.6  21.1  42.3   4.7
# 169   18      7  2012           33  68  15   0.0  86.1  23.9  51.6   5.2
# ..   ...    ...   ...          ...  ..  ..   ...   ...   ...   ...   ...
# 239   26      9  2012           30  65  14   0.0  85.4  16.0  44.5   4.5
# 240   27      9  2012           28  87  15   4.4  41.1   6.5     8   0.1
# 241   28      9  2012           27  87  29   0.5  45.9   3.5   7.9   0.4
# 242   29      9  2012           24  54  18   0.1  79.7   4.3  15.2   1.7
# 243   30      9  2012           24  64  15   0.2  67.3   3.8  16.5   1.2
#
#       BUI   FWI       Classes          region
# ...

# %%
df['DC'] = df['DC'].astype('float64')
df['FWI'] = df['FWI'].astype('float64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          244 non-null    int64
#  1   month        244 non-null    int64
#  2   year         244 non-null    int64
#  3   Temperature  244 non-null    int64
#  4   RH           244 non-null    int64
#  5   Ws           244 non-null    int64
#  6   Rain         244 non-null    float64
#  7   FFMC         244 non-null    float64
#  8   DMC          244 non-null    float64
#  9   DC           244 non-null    float64
#  10  ISI          244 non-null    float64
#  11  BUI          244 non-null    float64
#  12  FWI          244 non-null    float64
#  13  Classes      243 non-null    object
#  14  region       244 non-null    object
# dtypes: float64(7), int64(6), object(2)
# memory usage: 28.7+ KB

# %%
df.describe(include='all')
# Out:
#                day       month    year  Temperature          RH          Ws  \
# count   244.000000  244.000000   244.0   244.000000  244.000000  244.000000
# unique         NaN         NaN     NaN          NaN         NaN         NaN
# top            NaN         NaN     NaN          NaN         NaN         NaN
# freq           NaN         NaN     NaN          NaN         NaN         NaN
# mean     15.754098    7.500000  2012.0    32.172131   61.938525   15.504098
# std       8.825059    1.112961     0.0     3.633843   14.884200    2.810178
# min       1.000000    6.000000  2012.0    22.000000   21.000000    6.000000
# 25%       8.000000    7.000000  2012.0    30.000000   52.000000   14.000000
# 50%      16.000000    7.500000  2012.0    32.000000   63.000000   15.000000
# 75%      23.000000    8.000000  2012.0    35.000000   73.250000   17.000000
# max      31.000000    9.000000  2012.0    42.000000   90.000000   29.000000
#
# ...

# %%
df.isnull().sum()
# Out:
# day            0
# month          0
# year           0
# Temperature    0
# RH             0
# Ws             0
# Rain           0
# FFMC           0
# DMC            0
# DC             0
# ISI            0
# BUI            0
# FWI            0
# Classes        1
# region         0
# dtype: int64

# %%
df['Classes']=df['Classes'].fillna(df['Classes'].mode()[0])

# %%
num_feat = [i for i in df.columns if df[i].dtype!='O']
cat_feat = [i for i in df.columns if df[i].dtype=='O']

# %%
x_axis = num_feat # List
for x in x_axis:
    fig, axes = plt.subplots(1, 2, figsize=(18,4))
    sns.distplot(df[x], ax=axes[0], kde = False)
    sns.boxplot(df[x], ax=axes[1], orient = "h", showmeans = True, color = "pink")
    fig.suptitle('Univariate Analysis of ' + x, fontsize=16)

# %%
df['Classes'].unique()
# Out:
# array(['not fire   ', 'fire   ', 'fire', 'fire ', 'not fire', 'not fire ',
#        'not fire     ', 'not fire    '], dtype=object)

# %%
df['Classes'].value_counts()
# Out:
# fire             132
# not fire         101
# fire               4
# fire               2
# not fire           2
# not fire           1
# not fire           1
# not fire           1
# Name: Classes, dtype: int64

# %%
df['Classes'] = df['Classes'].str.strip()

# %%
df['Classes'].value_counts()
# Out:
# fire        138
# not fire    106
# Name: Classes, dtype: int64

# %%
df['Classes'].unique()
# Out:
# array(['not fire', 'fire'], dtype=object)

# %%
sns.countplot(df['Classes'])
# Out:
# <AxesSubplot:xlabel='Classes', ylabel='count'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          244 non-null    int64
#  1   month        244 non-null    int64
#  2   year         244 non-null    int64
#  3   Temperature  244 non-null    int64
#  4   RH           244 non-null    int64
#  5   Ws           244 non-null    int64
#  6   Rain         244 non-null    float64
#  7   FFMC         244 non-null    float64
#  8   DMC          244 non-null    float64
#  9   DC           244 non-null    float64
#  10  ISI          244 non-null    float64
#  11  BUI          244 non-null    float64
#  12  FWI          244 non-null    float64
#  13  Classes      244 non-null    object
#  14  region       244 non-null    object
# dtypes: float64(7), int64(6), object(2)
# memory usage: 28.7+ KB

# %%
plt.figure(figsize=(15, 15))
plt.suptitle('Univariate Analysis of Numerical Features', fontsize=20, fontweight='bold', alpha=0.8, y=1.)

for i in range(0, len(num_feat)):
    plt.subplot(5, 3, i+1)
    sns.kdeplot(x=df[num_feat[i]],shade=True, color='g')
    plt.xlabel(num_feat[i])
    plt.tight_layout()

# %%
# categorical columns
plt.figure(figsize=(20, 15))
plt.suptitle('Univariate Analysis of Categorical Features', fontsize=20, fontweight='bold', alpha=0.8, y=1.)
for i in range(0, len(cat_feat)):
    plt.subplot(2, 2, i+1)
    sns.countplot(x=df[cat_feat[i]])
    plt.xlabel(cat_feat[i])
    plt.xticks(rotation=45)
    plt.tight_layout()

# %%
df.head()
# Out:
#    day  month  year  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  \
# 0    1      6  2012           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4
# 1    2      6  2012           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9
# 2    3      6  2012           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7
# 3    4      6  2012           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7
# 4    5      6  2012           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9
#
#    FWI   Classes  region
# 0  0.5  not fire  Bejaia
# 1  0.4  not fire  Bejaia
# 2  0.1  not fire  Bejaia
# 3  0.0  not fire  Bejaia
# 4  0.5  not fire  Bejaia

# %%
x_axis = num_feat
y_axis = "FFMC"

for col in x_axis:
    sns.regplot(x = col, y = y_axis, data=df)
    plt.title("Scatter Plot of " + col + " & " + y_axis, fontsize = 15)
    plt.grid()
    plt.show()

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [day, month, year, Temperature, RH, Ws, Rain, FFMC, DMC, DC, ISI, BUI, FWI, Classes, region]
# Index: []

# %%
df.isna().sum()
# Out:
# day            0
# month          0
# year           0
# Temperature    0
# RH             0
# Ws             0
# Rain           0
# FFMC           0
# DMC            0
# DC             0
# ISI            0
# BUI            0
# FWI            0
# Classes        0
# region         0
# dtype: int64

# %%
sns.lineplot(x = 'Temperature',y = 'day',data = df)
# Out:
# <AxesSubplot:xlabel='Temperature', ylabel='day'>

# %%
sns.lineplot(x = 'Temperature',y = 'month',data = df)
# Out:
# <AxesSubplot:xlabel='Temperature', ylabel='month'>

# %%
df['month'].value_counts()
# Out:
# 7    62
# 8    62
# 6    60
# 9    60
# Name: month, dtype: int64

# %%
df.tail()
# Out:
#      day  month  year  Temperature  RH  Ws  Rain  FFMC   DMC    DC  ISI   BUI  \
# 239   26      9  2012           30  65  14   0.0  85.4  16.0  44.5  4.5  16.9
# 240   27      9  2012           28  87  15   4.4  41.1   6.5   8.0  0.1   6.2
# 241   28      9  2012           27  87  29   0.5  45.9   3.5   7.9  0.4   3.4
# 242   29      9  2012           24  54  18   0.1  79.7   4.3  15.2  1.7   5.1
# 243   30      9  2012           24  64  15   0.2  67.3   3.8  16.5  1.2   4.8
#
#      FWI   Classes          region
# 239  6.5      fire  Sidi-Bel Abbes
# 240  0.0  not fire  Sidi-Bel Abbes
# 241  0.2  not fire  Sidi-Bel Abbes
# 242  0.7  not fire  Sidi-Bel Abbes
# 243  0.5  not fire  Sidi-Bel Abbes

# %%
sns.relplot(y = 'Temperature',x = 'month',data = df,hue='Classes',style='region')

# %%
sns.relplot(y = 'Temperature',x = 'day',data = df,hue='Classes',style='region')

# %%
sns.barplot(y = 'Temperature',x = 'month',data = df,hue='Classes')
# Out:
# <AxesSubplot:xlabel='month', ylabel='Temperature'>

# %%
df = df.drop(['year'],axis=1)
df.head()
# Out:
#    day  month  Temperature  RH  Ws  Rain  FFMC  DMC    DC  ISI  BUI  FWI  \
# 0    1      6           29  57  18   0.0  65.7  3.4   7.6  1.3  3.4  0.5
# 1    2      6           29  61  13   1.3  64.4  4.1   7.6  1.0  3.9  0.4
# 2    3      6           26  82  22  13.1  47.1  2.5   7.1  0.3  2.7  0.1
# 3    4      6           25  89  13   2.5  28.6  1.3   6.9  0.0  1.7  0.0
# 4    5      6           27  77  16   0.0  64.8  3.0  14.2  1.2  3.9  0.5
#
#     Classes  region
# 0  not fire  Bejaia
# 1  not fire  Bejaia
# 2  not fire  Bejaia
# 3  not fire  Bejaia
# 4  not fire  Bejaia

# %%
df[(list(df.columns)[0:])].corr()
# Out:
#                       day         month  Temperature        RH        Ws  \
# day          1.000000e+00  2.232788e-17     0.095772 -0.074209  0.047001
# month        2.232788e-17  1.000000e+00    -0.059017 -0.037884 -0.041447
# Temperature  9.577222e-02 -5.901677e-02     1.000000 -0.654443 -0.278132
# RH          -7.420934e-02 -3.788419e-02    -0.654443  1.000000  0.236084
# Ws           4.700086e-02 -4.144673e-02    -0.278132  0.236084  1.000000
# Rain        -1.122654e-01  3.532207e-02    -0.326786  0.222968  0.170169
# FFMC         2.240321e-01  1.557668e-02     0.677491 -0.645658 -0.163255
# DMC          4.915710e-01  6.817778e-02     0.483105 -0.405133 -0.001246
# DC           5.279285e-01  1.276719e-01     0.370498 -0.220330  0.076245
# ISI          1.777266e-01  6.168011e-02     0.607551 -0.690637  0.015248
# BUI          5.172292e-01  8.582162e-02     0.455504 -0.348587  0.029756
# FWI          3.509095e-01  8.411895e-02     0.558800 -0.570483  0.029001
#
# ...

# %%
num_corr = df.corr()

mask = np.zeros_like(num_corr)

mask[np.triu_indices_from(mask)] = True

with sns.axes_style("white"):
    f, ax = plt.subplots(figsize=(18, 9))
    ax = sns.heatmap(num_corr , mask=mask, vmin = -1,vmax=1, annot = True, cmap="YlGnBu")

# %%
sns.scatterplot(x='BUI',y='DMC',data=df)
# Out:
# <AxesSubplot:xlabel='BUI', ylabel='DMC'>

# %%
fig, axes = plt.subplots(ncols=5,figsize=(20,4))
sns.boxplot(x='Classes',y='day',palette='PuBuGn_r',data=df, ax=axes[0])
axes[0].set_title('Day vs Classes')

sns.boxplot(x='Classes',y='month', palette='PuBuGn_r',data=df, ax=axes[1])
axes[1].set_title("month vs Classes")

sns.boxplot(x='Classes',y='Temperature', palette='PuBuGn_r',data=df, ax=axes[2])
axes[2].set_title("Temperature vs Classes")

sns.boxplot(x='Classes',y='RH' ,palette='PuBuGn_r',data=df, ax=axes[3])
axes[3].set_title("RH vs Classes")

sns.boxplot(x='Classes',y='Ws',palette='PuBuGn_r',data=df,ax=axes[4])
axes[4].set_title("Ws vs Classes")
# Out:
# Text(0.5, 1.0, 'Ws vs Classes')

# %%
fig, axes = plt.subplots(ncols=5,figsize=(20,4))
sns.boxplot(x='Classes',y='Rain',palette='PuBuGn_r',data=df,ax=axes[0])
axes[0].set_title("Rain vs Classes")

sns.boxplot(x='Classes',y='FFMC',palette='PuBuGn_r',data=df,ax=axes[1])
axes[1].set_title("FFMC vs Classes")

sns.boxplot(x='Classes',y='DMC',palette='PuBuGn_r',data=df,ax=axes[2])
axes[2].set_title("DMC vs Classes")

sns.boxplot(x='Classes',y='DC',palette='PuBuGn_r',data=df,ax=axes[3])
axes[3].set_title("DC vs Classes")

sns.boxplot(x='Classes',y='FWI',palette='PuBuGn_r',data=df,ax=axes[4])
axes[4].set_title("FWI vs Classes")
# Out:
# Text(0.5, 1.0, 'FWI vs Classes')

# %%
plt.style.use("default")
sns.barplot(df['day'],df['Temperature'])
plt.title("Day vs Temperature",fontsize=20)
plt.show()

# %%
plt.style.use("default")
sns.barplot(df['month'],df['Temperature'],hue=df['Classes'])
plt.title("Month vs Temperature",fontsize=20)
plt.show()

# %%
df.sort_values(by='Temperature', ascending=False)[['Temperature','day','month','region']].head(1)
# Out:
#      Temperature  day  month          region
# 199           42   17      8  Sidi-Bel Abbes

# %%
df.sort_values(by='Temperature', ascending=True)[['Temperature','day','month','region']].head(1)
# Out:
#      Temperature  day  month  region
# 105           22   14      9  Bejaia

# %%
df.sort_values(by='Rain', ascending=False)[['Rain','day','month','region']].head(1)
# Out:
#     Rain  day  month  region
# 91  16.8   31      8  Bejaia

# %%
df.sort_values(by='Rain', ascending=True)[['Rain','day','month','region']].head(1)
# Out:
#    Rain  day  month  region
# 0   0.0    1      6  Bejaia
